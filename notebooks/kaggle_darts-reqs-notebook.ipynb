# %%
# !pip install -qq darts --no-deps --target=/kaggle/working/ # See https://unit8co.github.io/darts/

# %%
# !pip install -qq pmdarima --no-deps --target=/kaggle/working/

# %%
# !pip install -qq nfoursid  --no-deps --target=/kaggle/working/

# %%
# !pip install -qq tbats  --no-deps --target=/kaggle/working/

# %%
# !pip install --quiet torch>=1.10.0 torchvision>=0.11.0 pytorch-lightning==1.9.0 torchmetrics==0.9.3 timm optuna==2.10.1 --no-deps --target=/kaggle/working/

# %%
from darts import TimeSeries
from darts.models import TiDEModel
from darts.dataprocessing.transformers import Scaler
from darts.utils.missing_values import fill_missing_values

# %%
import os
import warnings

import numpy as np
import matplotlib.pyplot as plt

import pandas as pd
import polars as pl

import torch
from torch import nn
